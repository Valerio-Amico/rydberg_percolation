# %%
from rydbperc import ryperc
import matplotlib.pyplot as plt

# %%
N_atoms = 4000

# %%
cloud = ryperc.cluster3D(size=N_atoms, is_2D=True)
cloud.set_evolution_parameters(
    shell_radius=0.1,
    shell_delta=0.001,
    blokade_radius=0.2,
    p_spont_exct=0.01/N_atoms,
    p_emission=0.1,
    p_fac=0.4
)

# %%
excitations = []
N_steps = 2000
for step in range(N_steps):
    cloud.evolution_step()
    excitations.append(len(cloud.cluster_excited))

# %%
plt.plot(excitations)
plt.show()

# %%
cloud.evolution_step()
excitations.append(len(cloud.cluster_excited))

# %%
cloud.show()
